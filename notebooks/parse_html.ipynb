# %% [markdown]
# ## Instalación

# %% [markdown]
# ## Configuración

# %%
from bs4 import BeautifulSoup
from requests import get
from time import sleep
import re

from pandas import DataFrame
from tqdm.notebook import tqdm


url = 'https://www.malaga.eu/la-ciudad/agenda/'

# %% [markdown]
# ### Peticiones web

# %%
response = get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# Podemos explorar el contenido de la respuesta con la siguiente función:

# %%
text = response.text

def preview_text(large_text: str) -> None:
    """
    Preview the first and last 300 characters of a large text.
    """
    print(f'{len(large_text) = }')
    print(f'{large_text[:300]}\n\n...\n\n{large_text[-300:]}')

preview_text(text)
# Out:
# len(large_text) = 111108
# <!DOCTYPE html>
# 	<html lang="es" itemscope="itemscope" itemtype="http://schema.org/Organization">
# 	<head>
#
# 		<title>Agenda</title>
# 		<meta charset="UTF-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1.0"> <meta name="descri
#
# ...
#
# src="/export/system/modules/com.saga.sagasuite.core.script/resources/respond/1.3.0/respond.js" type="text/javascript" ></script>
# 	<script src="/export/system/modules/com.saga.sagasuite.core.script/resources/sagasuite/sg-ie7-8.js" type="text/javascript" ></script>
# 	<![endif]-->
#
# 		</body>
#
# 	</html>

# %% [markdown]
# Es posible que una request como la anterior no nos devuelva el mismo resultado que recibimos utilizando nuestro explorador web. En ese caso, podemos intentar añadir headers que indiquen el navegador web que (teóricamente) estamos utilizando. En este caso, obtenemos el mismo resultado sin añadir estos headers, pero en muchas otras páginas esto no sucede así.

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/109.0'}

response = get(url, headers=headers)

text = response.text

preview_text(text)
# Out:
# len(large_text) = 111108
# <!DOCTYPE html>
# 	<html lang="es" itemscope="itemscope" itemtype="http://schema.org/Organization">
# 	<head>
#
# 		<title>Agenda</title>
# 		<meta charset="UTF-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge"><meta name="viewport" content="width=device-width, initial-scale=1.0"> <meta name="descri
#
# ...
#
# src="/export/system/modules/com.saga.sagasuite.core.script/resources/respond/1.3.0/respond.js" type="text/javascript" ></script>
# 	<script src="/export/system/modules/com.saga.sagasuite.core.script/resources/sagasuite/sg-ie7-8.js" type="text/javascript" ></script>
# 	<![endif]-->
#
# 		</body>
#
# 	</html>

# %% [markdown]
# Para procesar el html recibido utilizamos BeautifulSoup

# %%
soup = BeautifulSoup(response.text)
# soup

# %% [markdown]
# Después de haber explorado la página, sabemos que los eventos están en `<div id="agenda">`. Vamos a buscarlo.

# %%
events_container = soup.find('div', id='agenda')
events_container
# Out:
# <div class="element parent sg-search advanced sg-search-agenda" id="agenda">
# <div class="wrapper">
# <header class="headline">
# <h2 class="title h2">Agenda<a class="btn btn-gray rounded pull-right" href="https://www.malaga.eu/la-ciudad/dias-festivos/" target="_blank"><i aria-hidden="true" class="fa fa-calendar mr-5"></i>
# 					Dias Festivos</a>
# </h2>
# </header>
# <form class="sg-search-form sg-search-form-agenda mb-40" id="agd-searchform" method="get" name="agd-searchform" role="search">
# <div class="row">
# <div class="col-xxs-12 col-sm-5">
# <div class="filterheader clearfix mb-30">
# <span class="title-element">Calendario</span>
# </div>
# <div class="datepicker-wrapper datepicker-wrapper-inline datepicker-wrapper-with-caption" data-date-language="es" data-date-multidate="false" data-date-title="Selecciona un día para ver las actividades celebradas" data-date-today-highlight="true" data-date-week-start="1" data-provide="datepicker-inline" data-target-input="fechaDesde" id="calAgd">
# </div>
# </div>
# <div class="col-xxs-12 col-sm-7">
# <div class="filterheader clearfix mb-30">
# <span class="title-element">Buscador</span>
# </div>
# <div class="form-group mb-25">
# <div class="input-group">
# <span class="input-group-addon color-gray-light-medium">Desde</span>
# <input aria-label="Fecha desde (dd/mm/aaaa)" class="form-control" data-date-autoclose="true" data-date-language="es" data-date-multidate="false" data-date-today-highlight="true" data-date-week-start="1" data-provide="datepicker" data-target-input="fechaDesde" id="fechaDesde" name="fechaDesde" placeholder="dd/mm/aaaa" type="text" value=""/>
# <span class="input-group-addon input-group-addon-date-begin" data-date-autoclose="true" data-date-language="es" data-date-multidate="false" data-date-today-highlight="true" data-date-week-start="1" data-provide="datepicker" data-target-input="fechaDesde">
# <span aria-hidden="true" class="fa fa-calendar"></span>
# </span>
# </div>
# </div>
# <div class="form-group mb-25">
# <div class="input-group">
# <span class="input-group-addon color-gray-light-medium">Hasta</span>
# <input aria-label="Fecha hasta (dd/mm/aaaa)" class="form-control" data-date-autoclose="true" data-date-language="es" data-date-multidate="false" data-date-today-highlight="true" data-date-week-start="1" data-provide="datepicker" data-target-input="fechaHasta" id="fechaHasta" name="fechaHasta" placeholder="dd/mm/aaaa" type="text" value=""/>
# <span class="input-group-addon input-group-addon-date-begin" data-date-autoclose="true" data-date-language="es" data-date-multidate="false" data-date-today-highlight="true" data-date-week-start="1" data-provide="datepicker" data-target-input="fechaHasta">
# <span aria-hidden="true" class="fa fa-calendar"></span>
# </span>
# </div>
# </div>
# <div class="form-group mb-25">
# <input aria-label="Búsqueda por texto" class="form-control" id="texto" maxlength="50" name="texto" placeholder="Texto" type="text" value=""/>
# </div>
# <div class="form-group">
# <button class="btn btn-specific-main btn-lg btn-block" type="submit">Buscar</button>
# </div>
# </div>
# </div>
# </form>
# <div class="panel-group list">
# <ul class="list-unstyled main-ul mb-0">
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="Imagen principal" class="img-responsive" height="320" src="http://www.malaga.eu/inter/visor_contenido/AGDImageDisplayer1/ImagenAgenda51112?id_imagen=51112" width="480"/>
# </span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145861">XXX MUESTRA GASTRONÓMICA POPULAR CHURRIANA 2026</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <span>Desde</span>
# <time datetime="2026-04-06">
#                                     06-04-2026</time>
# <span> // </span>
# <span>Hasta</span>
# <time datetime="2026-05-09">
#                                     09-05-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>JARDINES GERALD BRENAN</span>
# </span>
# <div class="description">
# <p>
#                             El sábado 9 de Mayo, a las 14:00 h. disfrutaremos un año más de esta actividad gastronómica en
# Churriana, donde podremos disfrutar del arte culinario que tenemos en este Distrito 8. ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="Imagen principal" class="img-responsive" height="320" src="http://www.malaga.eu/inter/visor_contenido/AGDImageDisplayer1/ImagenAgenda51108?id_imagen=51108" width="480"/>
# </span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145860">IX CONCURSO ESCAPARATES FERIA CHURRIANA 2026</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <span>Desde</span>
# <time datetime="2026-04-06">
#                                     06-04-2026</time>
# <span> // </span>
# <span>Hasta</span>
# <time datetime="2026-05-14">
#                                     14-05-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>ESCAPARATES COMERCIOS DE CHURRIANA</span>
# </span>
# <div class="description">
# <p>
#                             CONCURSO ESCAPARATES FERIA CHURRIANA 2026
# Engalana tu Escaparate y apúntate al Concurso del Distrito
# Este año un único premio dotado con 700¿
# Plazo de Inscripción desde el día ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="Imagen principal" class="img-responsive" height="320" src="http://www.malaga.eu/inter/visor_contenido/AGDImageDisplayer1/ImagenAgenda50992?id_imagen=50992" width="480"/>
# </span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145434">"38º MUESTRA DE TEATRO" ÁREA DE EDUCACIÓN AYUNTAMIENTO DE MÁLAGA</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <time datetime="2026-04-08">
#                                     08-04-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>La Caja Blanca</span>
# </span>
# <div class="description">
# <p>
#                             Área de Educación del Ayuntamiento de Málaga
#
# Programa del Área de Educación dirigido a escolares de Educación Infantil, Primaria, ESO,
# Bachillerato y Ciclos Formativos. ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="" class="img-responsive" height="320" src="/export/shared/corporativas/default/agenda-l.png_1014274486.png" width="480"/></span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145637">Cita con el Tablero. Taller de Ajedrez Infantil. BPM Cristóbal Cuevas</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <time datetime="2026-04-08">
#                                     08-04-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>Biblioteca Pública Municipal "Cristóbal Cuevas" (Bailén-Miraflores)</span>
# </span>
# <div class="description">
# <p>
#                             Dirigido a: niños/as de 6 a 12 años. PREVIA INSCRIPCIÓN. Contenido: Taller de iniciación al ajedrez
# dirigido a los más pequeños y coordinado por Enrique Díaz Fernández. 2026/03/24 12:03:25</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="" class="img-responsive" height="320" src="/export/shared/corporativas/default/agenda-l.png_1014274486.png" width="480"/></span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145625">Club de Lectura para Adultos. BPM Vicente Espinel</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <time datetime="2026-04-08">
#                                     08-04-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>Biblioteca Pública Municipal "Vicente Espinel" (Puerto de la Torre)</span>
# </span>
# <div class="description">
# <p>
#                             Dirigido a: Adultos a partir de 18 años. PREVIA INSCRIPCIÓN. Contenido: La lectura es un placer que
# se disfruta en solitario pero se convierte en apasionante cuando las aventuras ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="" class="img-responsive" height="320" src="/export/shared/corporativas/default/agenda-l.png_1014274486.png" width="480"/></span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=144711">Taller de Poesía. B.P.M. Manuel Altolaguirre</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <time datetime="2026-04-08">
#                                     08-04-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>Biblioteca Pública Municipal "Manuel Altolaguirre" (Cruz)</span>
# </span>
# <div class="description">
# <p>
#                             Dirigido. Público adulto. PREVIA INSCRIPCIÓN TELEFÓNICA. Contenido. Taller de poesía donde se
# trabaja con distintos recursos poéticos dando a conocer poetas de diferentes etapas y ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="Imagen principal" class="img-responsive" height="320" src="http://www.malaga.eu/inter/visor_contenido/AGDImageDisplayer1/ImagenAgenda50993?id_imagen=50993" width="480"/>
# </span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145435">"38º MUESTRA DE TEATRO" ÁREA DE EDUCACIÓN AYUNTAMIENTO DE MÁLAGA</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <time datetime="2026-04-09">
#                                     09-04-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>La Caja Blanca</span>
# </span>
# <div class="description">
# <p>
#                             Área de Educación del Ayuntamiento de Málaga
#
# Programa del Área de Educación dirigido a escolares de Educación Infantil, Primaria, ESO,
# Bachillerato y Ciclos Formativos. ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="" class="img-responsive" height="320" src="/export/shared/corporativas/default/agenda-l.png_1014274486.png" width="480"/></span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145685">Voces Contemporáneas: Juan Gómez Bárcena</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <time datetime="2026-04-09">
#                                     09-04-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>Museo Centro de Arte Contemporáneo MUCAC Málaga - Sede La Coracha.</span>
# </span>
# <div class="description">
# <p>
#                             El autor Juan Gómez Bárcena (Santander, 1984), uno de los narradores más talentosos de su
# generación, presentará su novela Abril o nunca. ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="" class="img-responsive" height="320" src="/export/shared/corporativas/default/agenda-l.png_1014274486.png" width="480"/></span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145767">Exposición temporal ARCHIPIÉLAGO/S, arquitectura sin centro.</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <span>Desde</span>
# <time datetime="2026-04-09">
#                                     09-04-2026</time>
# <span> // </span>
# <span>Hasta</span>
# <time datetime="2026-08-30">
#                                     30-08-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>Salas de exposiciones La Coracha (MUCAC). Edificio 1, Espacio Cero. Málaga Sostenible.</span>
# </span>
# <div class="description">
# <p>
#                             La muestra, comisariada por Alvaro Carrillo (Málaga, 1986), presenta diversas maquetas de proyectos
# de arquitectura producidos en la última década por estudios e investigadores ...</p>
# </div>
# </div>
# </article>
# </li>
# <li class="list-element">
# <article class="media row lg-spacing-row">
# <div class="media-object col-xxs-12 col-xs-3">
# <div class="saga-imagen">
# <span class="wrapper-image">
# <img alt="" class="img-responsive" height="320" src="/export/shared/corporativas/default/agenda-l.png_1014274486.png" width="480"/></span>
# </div>
# </div>
# <div class="media-body container-fluid">
# <h2 class="title-element media-heading h3">
# <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145633">Cuentacuentos en Inglés. B.P.M. Vicente Espinel</a>
# </h2>
# <span class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <time datetime="2026-04-10">
#                                     10-04-2026</time>
# </span>
# <span class="info place-element">
# <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
# <span>Biblioteca Pública Municipal "Vicente Espinel" (Puerto de la Torre)</span>
# </span>
# <div class="description">
# <p>
#                             Dirigido a: Niñas y niños de 4 a 10 años. PREVIA INSCRIPCIÓN. Contenido: Son sesiones de
# cuentacuentos en lengua inglesa, impartido por la academia Kids &amp; Us.</p>
# </div>
# </div>
# </article>
# </li>
# </ul>
# </div>
# </div>
# </div>

# %% [markdown]
# Dentro, podemos quedarnos con la información de cada evento, que está en un `<article class="media row">`

# %%
events = events_container.find_all('article', class_='media')

print(f"Eventos en la página: {len(events)}")
events[:2]
# Out:
# Eventos en la página: 10
# [<article class="media row lg-spacing-row">
#  <div class="media-object col-xxs-12 col-xs-3">
#  <div class="saga-imagen">
#  <span class="wrapper-image">
#  <img alt="Imagen principal" class="img-responsive" height="320" src="http://www.malaga.eu/inter/visor_contenido/AGDImageDisplayer1/ImagenAgenda51112?id_imagen=51112" width="480"/>
#  </span>
#  </div>
#  </div>
#  <div class="media-body container-fluid">
#  <h2 class="title-element media-heading h3">
#  <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145861">XXX MUESTRA GASTRONÓMICA POPULAR CHURRIANA 2026</a>
#  </h2>
#  <span class="info date-element">
#  <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
#  <span>Desde</span>
#  <time datetime="2026-04-06">
#                                      06-04-2026</time>
#  <span> // </span>
#  <span>Hasta</span>
#  <time datetime="2026-05-09">
#                                      09-05-2026</time>
#  </span>
#  <span class="info place-element">
#  <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
#  <span>JARDINES GERALD BRENAN</span>
#  </span>
#  <div class="description">
#  <p>
#                              El sábado 9 de Mayo, a las 14:00 h. disfrutaremos un año más de esta actividad gastronómica en
#  Churriana, donde podremos disfrutar del arte culinario que tenemos en este Distrito 8. ...</p>
#  </div>
#  </div>
#  </article>,
#  <article class="media row lg-spacing-row">
#  <div class="media-object col-xxs-12 col-xs-3">
#  <div class="saga-imagen">
#  <span class="wrapper-image">
#  <img alt="Imagen principal" class="img-responsive" height="320" src="http://www.malaga.eu/inter/visor_contenido/AGDImageDisplayer1/ImagenAgenda51108?id_imagen=51108" width="480"/>
#  </span>
#  </div>
#  </div>
#  <div class="media-body container-fluid">
#  <h2 class="title-element media-heading h3">
#  <a href="/la-ciudad/agenda/detalle-actividad/index.html?id=145860">IX CONCURSO ESCAPARATES FERIA CHURRIANA 2026</a>
#  </h2>
#  <span class="info date-element">
#  <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
#  <span>Desde</span>
#  <time datetime="2026-04-06">
#                                      06-04-2026</time>
#  <span> // </span>
#  <span>Hasta</span>
#  <time datetime="2026-05-14">
#                                      14-05-2026</time>
#  </span>
#  <span class="info place-element">
#  <span aria-hidden="true" class="pe-7s-map-marker fs30 v-align-m mr-10"></span>
#  <span>ESCAPARATES COMERCIOS DE CHURRIANA</span>
#  </span>
#  <div class="description">
#  <p>
#                              CONCURSO ESCAPARATES FERIA CHURRIANA 2026
#  Engalana tu Escaparate y apúntate al Concurso del Distrito
#  Este año un único premio dotado con 700¿
#  Plazo de Inscripción desde el día ...</p>
#  </div>
#  </div>
#  </article>]

# %% [markdown]
# Explorando más, podemos ver que para cada evento tenemos un link a su página de detalle. Vamos a recopilar todas las urls de los eventos.

# %%
event_links = [
    event.find("h2").find("a")["href"] for event in events
]

event_links
# Out:
# ['/la-ciudad/agenda/detalle-actividad/index.html?id=145861',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145860',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145434',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145637',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145625',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=144711',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145435',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145685',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145767',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145633']

# %% [markdown]
# Exploramos lo que aparece en una página de evento

# %%
base_url = 'https://www.malaga.eu'

event = event_links[0]

html_e = get(f'{base_url}{event}', headers=headers)

soup = BeautifulSoup(html_e.text)
# Como antes, nos quedamos con la parte que contiene la información del evento
soup = soup.find("article")
soup
# Out:
# <article class="articulo element parent sg-actividad">
# <div class="wrapper">
# <header class="headline">
# <h1 class="title">XXX MUESTRA GASTRONÓMICA POPULAR CHURRIANA 2026</h1>
# </header>
# <div class="contentblock">
# <div class="contentblock-texto row">
# <div class="media-object image col-xxs-12 col-sm-5 pull-right pos-right">
# <div class="saga-imagen">
# <a class="wrapper-image zoom-filter" data-title="XXX MUESTRA GASTRONÓMICA POPULAR CHURRIANA 2026" href="https://www.malaga.eu/visorcontenido/AGDImageDisplayer1/51112/ImagenAgenda51112" title="Ampliar imagen agenda-l">
# <div class="overlay-zoom">
# <img alt="XXX MUESTRA GASTRONÓMICA POPULAR CHURRIANA 2026" class="img-responsive" height="300" src="https://www.malaga.eu/visorcontenido/AGDImageDisplayer1/51112/ImagenAgenda51112" width="440"/>
# <div class="zoom-icon">
# <span aria-hidden="true" class="fa fa-expand"></span>
# </div>
# </div>
# </a>
# <span class="saga-imagen-pie"><span class="saga-imagen-pie-content"><!-- Pie de imagen --></span></span>
# </div>
# </div>
# <div class="container-fluid">
# <div class="info-wrapper">
# <div class="info date-element">
# <span aria-hidden="true" class="pe-7s-date fs30 v-align-m mr-10"></span>
# <span>Desde</span>
# <time datetime="1775426400000">
#                                     6/4/2026</time>
# <span> // </span>
# <span>Hasta</span>
# <time datetime="1778277600000">
#                                     9/5/2026</time>
# </div>
# </div>
# <p>El sábado 9 de Mayo, a las 14:00 h. disfrutaremos un año más de esta actividad gastronómica en Churriana, donde podremos disfrutar del arte culinario que tenemos en este Distrito 8.
# <br/>
# <br/>
# El concurso tendrá lugar en los Jardines Gerald Brenan, situados en la Plaza de la Inmaculada 11, a las 14:00 h.
# <br/>
# <br/> Las solicitudes se podrán presentar preferentemente por la Sede Electrónica o en la OMAC Nº 8 Churriana (Pza. de la Inmaculada) en horario de 9:00 a 14:00 h.
# <br/><br/>
# Se otorgarán 3 premios en cada modalidad: salados y postres.
# <br/><br/>
# <b>Primer premio: 250 Euros
# <br/>
# <b>Segundo premio: 200 Euros
# <br/>
# <b>Tercer premio: 150 Euros<b>
# <br/>
# <br/>
# Los concursantes podrán presentar todos los platos que deseen en cualquiera de las dos modalidades; no obstante sólo podrá recibir un premio entre las dos categorías.
# <br/>
# El fallo del jurado se dará a conocer el mismo día 09 de mayo de 2026.
# <br/><br/>
# ¿Te animas a participar?</b></b></b></b></p>
# <div class="h3">Ficha Informativa</div>
# <dl class="dl-horizontal dl-basic">
# <dt>Evento:</dt>
# <dd>FERIA POPULAR DE CHURRIANA 2026 - SAN ISIDRO LABRADOR</dd>
# <dt>Otros lugares:</dt>
# <dd>JARDINES GERALD BRENAN</dd>
# <dt>Horario:</dt>
# <dd>A PARTIR DE LAS 14:00 HORAS</dd>
# <dt>Teléfono:</dt>
# <dd>951 92 60 48 - 951 92 93 71</dd>
# <dt>Precio:</dt>
# <dd>GRATUITO</dd>
# <dt>Fecha Inscripción:</dt>
# <dd>
#
#                             Desde
#                             <time datetime="1778277600000">
#                                     6/4/2026</time>
#
#                             Hasta
#                             <time datetime="1778277600000">
#                                     9/5/2026</time>
# </dd>
# <dt>Destinatarios:</dt>
# <dd>
#
#                                Todas la edades
#                             </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </article>

# %% [markdown]
# Una función para obtener la información de un evento a partir de esta url:

# %%
def get_event_info(event_link: str) -> dict:

    html = get(f'{base_url}{event_link}', headers=headers)
    soup = BeautifulSoup(html.text)
    base = {'event_link': event_link}

    try:
        div_info = soup.find("article")
    # El manejo de errores se puede mejorar (debemos comprobar los errores que podemos recibir)
    except:
        # Si no encontramos el div_info, devolvemos un diccionario con solo el link del evento
        return base

    info = {
        # Detecta el tag <h1>, y nos quedamos con el contenido de "text"
        'title': div_info.h1.text.strip(),
        # Detecta las fechas en el tag <div class="info date-element">:
        "dates": [t.text.strip() for t in div_info.find("div", class_="date-element").find_all("time")],
        # Detecta el único elemento <p> de los datos del evento
        "description": div_info.find("p").text.strip(),
        # Guardamos el texto bajo el título "Ficha informativa". Lo podemos guardar como datos menos estructurados para analizarlos luego
        # Además, limpiamos un poco el texto mediante expresiones regulares.
        # `re.sub(r" {2,}", " ", text)` sustituye los espacios en blanco que van seguidos por un solo espacio
        "info": re.sub(r" {2,}", " ", div_info.find("div", class_="h3").find_next_sibling().get_text()).strip(),
    }
    # Detecta el tag <img class="img-responsive">, y nos quedamos con el contenido de "src"
    if (img_data := div_info.find("img", class_="img-responsive")) is not None:
       info["img_url"] = img_data["src"]

    # Algunos eventos tienen la información de la ubicación
    try:
        location_elem = div_info.find("div", class_="place-element").find("a")
        location = {
            'location_url': location_elem["href"],
            'location_name': location_elem.text.strip()
        }
    except:
        location = {}
    return {**base, **info, **location}


get_event_info(event_links[1])
# Out:
# {'event_link': '/la-ciudad/agenda/detalle-actividad/index.html?id=145860',
#  'title': 'IX CONCURSO ESCAPARATES FERIA CHURRIANA 2026',
#  'dates': ['6/4/2026', '14/5/2026'],
#  'description': 'CONCURSO ESCAPARATES FERIA CHURRIANA 2026\r\n\r\nEngalana tu Escaparate y apúntate al Concurso del Distrito\r\n\r\nEste año un único premio dotado con 700¿\r\n\r\nPlazo de Inscripción desde el día siguiente a su publicación y hasta el 4 de mayo de 2026.\r\n\r\nLas visitas a los comercios se realizarán los días 6 y 7 de mayo.\r\n\r\nLa Resolución que se dará a conocer el día 14 de mayo en la Caseta Municipal del Recinto Ferial a las 22:30 horas.',
#  'info': 'Evento:\nFERIA POPULAR DE CHURRIANA 2026 - SAN ISIDRO LABRADOR\nOtros lugares:\nESCAPARATES COMERCIOS DE CHURRIANA\nHorario:\nHORARIO COMERCIAL\nTeléfono:\n951 92 60 48\nPrecio:\nGRATUITO\nFecha Inscripción:\n\n \n Desde \n \n 6/4/2026\n \n Hasta \n \n 4/5/2026\n\nDestinatarios:\n\n \n Todas la edades',
#  'img_url': 'https://www.malaga.eu/visorcontenido/AGDImageDisplayer1/51111/ImagenAgenda51111'}

# %% [markdown]
# Ahora podemos recopilar todos los eventos de la página. Antes recogimos solo los eventos de la primera página. Vamos a recorrer todas las páginas de eventos.

# %%
page_idxs = range(1, 7)  # 6 páginas de eventos

# Recorremos las páginas de eventos
# La librería `tqdm` nos permite mostrar una barra de progreso
for page_idx in tqdm(page_idxs):
    url = f'https://www.malaga.eu/la-ciudad/agenda/index.html?mas=true&pageNum={page_idx}'
    html = get(url, headers=headers)
    soup = BeautifulSoup(html.text)
    # Repetimos el proceso anterior para obtener los links de los eventos
    events_container = soup.find('div', id='agenda')
    events = events_container.find_all('article', class_='media')
    event_links += [event.find("h2").find("a")["href"] for event in events]
    # Esperamos un segundo entre peticiones para no saturar el servidor de la página que estamos scrapeando
    sleep(1)

print(f"Eventos encontrados: {len(event_links)}")
# Mostramos los dos primeros
event_links[:2]
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Eventos encontrados: 70
# ['/la-ciudad/agenda/detalle-actividad/index.html?id=145861',
#  '/la-ciudad/agenda/detalle-actividad/index.html?id=145860']

# %% [markdown]
# Por último, recorremos las urls de los eventos que hemos encontrado para guardar su información

# %%
events_info = []
for event_link in tqdm(event_links):
    events_info.append(get_event_info(event_link))
    sleep(.5)

len(events_info)
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
# 70

# %% [markdown]
# Podemos poner la respuesta como una tabla

# %%
df = DataFrame(events_info)
df
# Out:
#                                            event_link  \
# 0   /la-ciudad/agenda/detalle-actividad/index.html...
# 1   /la-ciudad/agenda/detalle-actividad/index.html...
# 2   /la-ciudad/agenda/detalle-actividad/index.html...
# 3   /la-ciudad/agenda/detalle-actividad/index.html...
# 4   /la-ciudad/agenda/detalle-actividad/index.html...
# ..                                                ...
# 58  /la-ciudad/agenda/detalle-actividad/index.html...
# 59  /la-ciudad/agenda/detalle-actividad/index.html...
# 60  /la-ciudad/agenda/detalle-actividad/index.html...
# 61  /la-ciudad/agenda/detalle-actividad/index.html...
# 62  /la-ciudad/agenda/detalle-actividad/index.html...
#
#                                                 title  \
# 0              Manipulador de Alimentos para Celíacos
# 1   Cita con el Tablero. Taller de Ajedrez Infanti...
# 2                       Día del Libro: Irene Vallejo.
# 3   TEATRO "EL CIRCO DE LAS EMOCIONES" C.E.I.P. PR...
# 4   Taller de Poesía Grupo 21. B.P.M. Manuel Altol...
# ..                                                ...
# 58                             Taller de manualidades
# 59                                   Terapia de grupo
# 60         Simed, Salón Inmobiliario del Mediterráneo
# 61                        Picasso. Imágenes cerámicas
# 62               Museo del Vidrio y Cristal de Málaga
#
#                        dates  \
# 0     [23/4/2025, 23/4/2025]
# 1     [23/4/2025, 23/4/2025]
# 2     [23/4/2025, 23/4/2025]
# 3     [23/4/2025, 23/4/2025]
# 4     [23/4/2025, 23/4/2025]
# ..                       ...
# 58    [4/10/2024, 4/10/2025]
# 59    [4/10/2024, 4/10/2025]
# 60  [13/11/2025, 15/11/2025]
# 61    [14/6/2024, 6/10/2025]
# 62    [15/7/2010, 15/7/2100]
#
#                                           description  \
# 0   El carnet de manipulador de alimentos es un ce...
# 1   Dirigido a: niños/as de 6 a 12 años. PREVIA IN...
# 2   Charlará con la autora Ana Cabello, gerente de...
# 3   Representación teatral correspondiente al proy...
# 4   Dirigido. Público adulto. PREVIA INSCRIPCIÓN\r...
# ..                                                ...
# 58  Taller de manualidades donde se practican y ap...
# 59  Sesiones de Terapia de grupo en relación a asp...
# 60  El evento líder del sector residencial especia...
# 61  La cerámica de Picasso ha sido injustamente vi...
# 62  Exposicion permanenete en el Museo del Vidrio ...
#
#                                                  info  \
# 0   Evento:\nIMFE: Jornadas y seminarios \nOtros l...
# 1   Evento:\nPlan de Fomento a la Lectura en las B...
# 2   Evento:\nFundación Rafael Pérez Estrada\nHorar...
# 3   Evento:\nLA CAJA BLANCA - Auditorio 2025\nHora...
# 4   Evento:\nPlan de Fomento a la Lectura en las B...
# ..                                                ...
# 58  Evento:\nACTIVIDADES AMFAEM 2024-25\nOtros lug...
# 59  Evento:\nACTIVIDADES AMFAEM 2024-25\nOtros lug...
# 60  Evento:\nSimed ¿ Salón Inmobiliario del Medite...
# 61  Evento:\nMuseo Casa Natal Picasso\nHorario:\nD...
# 62  Evento:\nExposición de la colección de Gonzalo...
#
#                                               img_url  \
# 0   https://www.malaga.eu/visorcontenido/AGDImageD...
# 1    /export/shared/corporativas/default/agenda-l.png
# 2    /export/shared/corporativas/default/agenda-l.png
# 3                                                 NaN
# 4    /export/shared/corporativas/default/agenda-l.png
# ..                                                ...
# 58   /export/shared/corporativas/default/agenda-l.png
# 59   /export/shared/corporativas/default/agenda-l.png
# 60  https://www.malaga.eu/visorcontenido/AGDImageD...
# 61   /export/shared/corporativas/default/agenda-l.png
# 62   /export/shared/corporativas/default/agenda-l.png
#
#                                          location_url  \
# 0                                                 NaN
# 1   /la-ciudad/instalaciones-y-espacios/detalle-de...
# 2   /la-ciudad/instalaciones-y-espacios/detalle-de...
# 3   /la-ciudad/instalaciones-y-espacios/detalle-de...
# 4   /la-ciudad/instalaciones-y-espacios/detalle-de...
# ..                                                ...
# 58                                                NaN
# 59                                                NaN
# 60  /la-ciudad/instalaciones-y-espacios/detalle-de...
# 61  /la-ciudad/instalaciones-y-espacios/detalle-de...
# 62                                                NaN
#
#                                         location_name
# 0                                                 NaN
# 1   Biblioteca Pública Municipal "Cristóbal Cuevas...
# 2                              Centre Pompidou Málaga
# 3                                      La Caja Blanca
# 4   Biblioteca Pública Municipal "Manuel Altolagui...
# ..                                                ...
# 58                                                NaN
# 59                                                NaN
# 60            Palacio de Ferias y Congresos de Málaga
# 61                           Museo Casa Natal Picasso
# 62                                                NaN
#
# [63 rows x 8 columns]

# %%
df.to_csv('malaga_events_20260416.csv', index=False)
